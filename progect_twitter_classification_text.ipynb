# %%
#Load the dataset using pandas and store it in a DataFrame, such as data.
import numpy as np
import pandas as pd
data=pd.read_csv("Tweets.csv")
data
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 1                         NaN                     0.0000  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# ...                       ...                        ...             ...
# 14635                     NaN                     0.0000        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold             name negativereason_gold  \
# 0                        NaN          cairdin                 NaN
# 1                        NaN         jnardino                 NaN
# 2                        NaN       yvonnalynn                 NaN
# 3                        NaN         jnardino                 NaN
# 4                        NaN         jnardino                 NaN
# ...                      ...              ...                 ...
# 14635                    NaN  KristenReenders                 NaN
# 14636                    NaN         itsropes                 NaN
# 14637                    NaN         sanyabun                 NaN
# 14638                    NaN       SraJackson                 NaN
# 14639                    NaN        daviddtwu                 NaN
#
#        retweet_count                                               text  \
# 0                  0                @VirginAmerica What @dhepburn said.
# 1                  0  @VirginAmerica plus you've added commercials t...
# 2                  0  @VirginAmerica I didn't today... Must mean I n...
# 3                  0  @VirginAmerica it's really aggressive to blast...
# 4                  0  @VirginAmerica and it's a really big bad thing...
# ...              ...                                                ...
# 14635              0  @AmericanAir thank you we got on a different f...
# 14636              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14637              0  @AmericanAir Please bring American Airlines to...
# 14638              0  @AmericanAir you have my money, you change my ...
# 14639              0  @AmericanAir we have 8 ppl so we need 2 know h...
#
#       tweet_coord              tweet_created tweet_location  \
# 0             NaN  2015-02-24 11:35:52 -0800            NaN
# 1             NaN  2015-02-24 11:15:59 -0800            NaN
# 2             NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3             NaN  2015-02-24 11:15:36 -0800            NaN
# 4             NaN  2015-02-24 11:14:45 -0800            NaN
# ...           ...                        ...            ...
# 14635         NaN  2015-02-22 12:01:01 -0800            NaN
# 14636         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone
# 0      Eastern Time (US & Canada)
# 1      Pacific Time (US & Canada)
# 2      Central Time (US & Canada)
# 3      Pacific Time (US & Canada)
# 4      Pacific Time (US & Canada)
# ...                           ...
# 14635                         NaN
# 14636                         NaN
# 14637                         NaN
# 14638  Eastern Time (US & Canada)
# 14639                         NaN
#
# [14640 rows x 15 columns]

# %%
#verifying the missing data
data.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
#Clean the dataset by removing rows with low confidence levels (airline_sentiment_confidence <= 0.65).
data = data.drop(data[data['airline_sentiment_confidence'] <= 0.65].index)
data
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# 5      570300767074181121          negative                        1.0000
# ...                   ...               ...                           ...
# 14634  569587691626622976          negative                        0.6684
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                     0.6684        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN        cairdin                 NaN
# 2                        NaN     yvonnalynn                 NaN
# 3                        NaN       jnardino                 NaN
# 4                        NaN       jnardino                 NaN
# 5                        NaN       jnardino                 NaN
# ...                      ...            ...                 ...
# 14634                    NaN  GolfWithWoody                 NaN
# 14636                    NaN       itsropes                 NaN
# 14637                    NaN       sanyabun                 NaN
# 14638                    NaN     SraJackson                 NaN
# 14639                    NaN      daviddtwu                 NaN
#
#        retweet_count                                               text  \
# 0                  0                @VirginAmerica What @dhepburn said.
# 2                  0  @VirginAmerica I didn't today... Must mean I n...
# 3                  0  @VirginAmerica it's really aggressive to blast...
# 4                  0  @VirginAmerica and it's a really big bad thing...
# 5                  0  @VirginAmerica seriously would pay $30 a fligh...
# ...              ...                                                ...
# 14634              0         @AmericanAir right on cue with the delays👌
# 14636              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14637              0  @AmericanAir Please bring American Airlines to...
# 14638              0  @AmericanAir you have my money, you change my ...
# 14639              0  @AmericanAir we have 8 ppl so we need 2 know h...
#
#       tweet_coord              tweet_created tweet_location  \
# 0             NaN  2015-02-24 11:35:52 -0800            NaN
# 2             NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3             NaN  2015-02-24 11:15:36 -0800            NaN
# 4             NaN  2015-02-24 11:14:45 -0800            NaN
# 5             NaN  2015-02-24 11:14:33 -0800            NaN
# ...           ...                        ...            ...
# 14634         NaN  2015-02-22 12:01:02 -0800            NaN
# 14636         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone
# 0      Eastern Time (US & Canada)
# 2      Central Time (US & Canada)
# 3      Pacific Time (US & Canada)
# 4      Pacific Time (US & Canada)
# 5      Pacific Time (US & Canada)
# ...                           ...
# 14634                       Quito
# 14636                         NaN
# 14637                         NaN
# 14638  Eastern Time (US & Canada)
# 14639                         NaN
#
# [13651 rows x 15 columns]

# %%
#Create a new column sentiment based on the airline_sentiment, where negative sentiment is encoded as 1 and non-negative sentiment as 0.
data['sentiment'] = data['airline_sentiment'].apply(lambda x: 1 if x == 'negative' else 0)

# %%
data
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# 5      570300767074181121          negative                        1.0000
# ...                   ...               ...                           ...
# 14634  569587691626622976          negative                        0.6684
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                     0.6684        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN        cairdin                 NaN
# 2                        NaN     yvonnalynn                 NaN
# 3                        NaN       jnardino                 NaN
# 4                        NaN       jnardino                 NaN
# 5                        NaN       jnardino                 NaN
# ...                      ...            ...                 ...
# 14634                    NaN  GolfWithWoody                 NaN
# 14636                    NaN       itsropes                 NaN
# 14637                    NaN       sanyabun                 NaN
# 14638                    NaN     SraJackson                 NaN
# 14639                    NaN      daviddtwu                 NaN
#
#        retweet_count                                               text  \
# 0                  0                @VirginAmerica What @dhepburn said.
# 2                  0  @VirginAmerica I didn't today... Must mean I n...
# 3                  0  @VirginAmerica it's really aggressive to blast...
# 4                  0  @VirginAmerica and it's a really big bad thing...
# 5                  0  @VirginAmerica seriously would pay $30 a fligh...
# ...              ...                                                ...
# 14634              0         @AmericanAir right on cue with the delays👌
# 14636              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14637              0  @AmericanAir Please bring American Airlines to...
# 14638              0  @AmericanAir you have my money, you change my ...
# 14639              0  @AmericanAir we have 8 ppl so we need 2 know h...
#
#       tweet_coord              tweet_created tweet_location  \
# 0             NaN  2015-02-24 11:35:52 -0800            NaN
# 2             NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3             NaN  2015-02-24 11:15:36 -0800            NaN
# 4             NaN  2015-02-24 11:14:45 -0800            NaN
# 5             NaN  2015-02-24 11:14:33 -0800            NaN
# ...           ...                        ...            ...
# 14634         NaN  2015-02-22 12:01:02 -0800            NaN
# 14636         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636                         NaN          1
# 14637                         NaN          0
# 14638  Eastern Time (US & Canada)          1
# 14639                         NaN          0
#
# [13651 rows x 16 columns]

# %%
#removing the parce from the text using beautifulsoup 
from bs4 import BeautifulSoup
import re
def clean_text(text):
    # Remove HTML tags using BeautifulSoup
    cleaned = BeautifulSoup(text, 'html.parser').get_text()
    # Remove special characters and non-alphanumeric characters
    cleaned = re.sub(r'[^a-zA-Z0-9\s]', ' ', cleaned)
    # Remove extra spaces and convert to lowercase
    cleaned = ' '.join(cleaned.split()).lower()
    return cleaned

# %%
#creating new column with the clean text
data['text_clean'] = data['text'].apply(clean_text)
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
data
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# 5      570300767074181121          negative                        1.0000
# ...                   ...               ...                           ...
# 14634  569587691626622976          negative                        0.6684
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                     0.6684        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN        cairdin                 NaN
# 2                        NaN     yvonnalynn                 NaN
# 3                        NaN       jnardino                 NaN
# 4                        NaN       jnardino                 NaN
# 5                        NaN       jnardino                 NaN
# ...                      ...            ...                 ...
# 14634                    NaN  GolfWithWoody                 NaN
# 14636                    NaN       itsropes                 NaN
# 14637                    NaN       sanyabun                 NaN
# 14638                    NaN     SraJackson                 NaN
# 14639                    NaN      daviddtwu                 NaN
#
#        retweet_count                                               text  \
# 0                  0                @VirginAmerica What @dhepburn said.
# 2                  0  @VirginAmerica I didn't today... Must mean I n...
# 3                  0  @VirginAmerica it's really aggressive to blast...
# 4                  0  @VirginAmerica and it's a really big bad thing...
# 5                  0  @VirginAmerica seriously would pay $30 a fligh...
# ...              ...                                                ...
# 14634              0         @AmericanAir right on cue with the delays👌
# 14636              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14637              0  @AmericanAir Please bring American Airlines to...
# 14638              0  @AmericanAir you have my money, you change my ...
# 14639              0  @AmericanAir we have 8 ppl so we need 2 know h...
#
#       tweet_coord              tweet_created tweet_location  \
# 0             NaN  2015-02-24 11:35:52 -0800            NaN
# 2             NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3             NaN  2015-02-24 11:15:36 -0800            NaN
# 4             NaN  2015-02-24 11:14:45 -0800            NaN
# 5             NaN  2015-02-24 11:14:33 -0800            NaN
# ...           ...                        ...            ...
# 14634         NaN  2015-02-22 12:01:02 -0800            NaN
# 14636         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment  \
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636                         NaN          1
# 14637                         NaN          0
# 14638  Eastern Time (US & Canada)          1
# 14639                         NaN          0
#
#                                               text_clean
# 0                       virginamerica what dhepburn said
# 2      virginamerica i didn t today must mean i need ...
# 3      virginamerica it s really aggressive to blast ...
# 4      virginamerica and it s a really big bad thing ...
# 5      virginamerica seriously would pay 30 a flight ...
# ...                                                  ...
# 14634           americanair right on cue with the delays
# 14636  americanair leaving over 20 minutes late fligh...
# 14637  americanair please bring american airlines to ...
# 14638  americanair you have my money you change my fl...
# 14639  americanair we have 8 ppl so we need 2 know ho...
#
# [13651 rows x 17 columns]

# %%
#removing the previous column 'text' and 'airline_sentiment with new one'
data = data.drop(['airline_sentiment', 'text'], axis=1)

# %%
data
# Out:
#                  tweet_id  airline_sentiment_confidence  \
# 0      570306133677760513                        1.0000
# 2      570301083672813571                        0.6837
# 3      570301031407624196                        1.0000
# 4      570300817074462722                        1.0000
# 5      570300767074181121                        1.0000
# ...                   ...                           ...
# 14634  569587691626622976                        0.6684
# 14636  569587371693355008                        1.0000
# 14637  569587242672398336                        1.0000
# 14638  569587188687634433                        1.0000
# 14639  569587140490866689                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                     0.6684        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN        cairdin                 NaN
# 2                        NaN     yvonnalynn                 NaN
# 3                        NaN       jnardino                 NaN
# 4                        NaN       jnardino                 NaN
# 5                        NaN       jnardino                 NaN
# ...                      ...            ...                 ...
# 14634                    NaN  GolfWithWoody                 NaN
# 14636                    NaN       itsropes                 NaN
# 14637                    NaN       sanyabun                 NaN
# 14638                    NaN     SraJackson                 NaN
# 14639                    NaN      daviddtwu                 NaN
#
#        retweet_count tweet_coord              tweet_created tweet_location  \
# 0                  0         NaN  2015-02-24 11:35:52 -0800            NaN
# 2                  0         NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3                  0         NaN  2015-02-24 11:15:36 -0800            NaN
# 4                  0         NaN  2015-02-24 11:14:45 -0800            NaN
# 5                  0         NaN  2015-02-24 11:14:33 -0800            NaN
# ...              ...         ...                        ...            ...
# 14634              0         NaN  2015-02-22 12:01:02 -0800            NaN
# 14636              0         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637              0         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638              0         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639              0         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment  \
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636                         NaN          1
# 14637                         NaN          0
# 14638  Eastern Time (US & Canada)          1
# 14639                         NaN          0
#
#                                               text_clean
# 0                       virginamerica what dhepburn said
# 2      virginamerica i didn t today must mean i need ...
# 3      virginamerica it s really aggressive to blast ...
# 4      virginamerica and it s a really big bad thing ...
# 5      virginamerica seriously would pay 30 a flight ...
# ...                                                  ...
# 14634           americanair right on cue with the delays
# 14636  americanair leaving over 20 minutes late fligh...
# 14637  americanair please bring american airlines to ...
# 14638  americanair you have my money you change my fl...
# 14639  americanair we have 8 ppl so we need 2 know ho...
#
# [13651 rows x 15 columns]

# %%
#clearing the NAN values
data.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment_confidence        0
# negativereason                   4864
# negativereason_confidence        3931
# airline                             0
# airline_sentiment_gold          13612
# name                                0
# negativereason_gold             13619
# retweet_count                       0
# tweet_coord                     12691
# tweet_created                       0
# tweet_location                   4406
# user_timezone                    4514
# sentiment                           0
# text_clean                          0
# dtype: int64

# %%
data['negativereason'].value_counts()
# Out:
# Customer Service Issue         2833
# Late Flight                    1605
# Can't Tell                     1103
# Cancelled Flight                805
# Lost Luggage                    696
# Bad Flight                      553
# Flight Booking Problems         484
# Flight Attendant Complaints     467
# longlines                       169
# Damaged Luggage                  72
# Name: negativereason, dtype: int64

# %%
data['negativereason_gold'].value_counts()
# Out:
# Customer Service Issue                      12
# Late Flight                                  4
# Can't Tell                                   3
# Cancelled Flight                             3
# Cancelled Flight\nCustomer Service Issue     2
# Late Flight\nFlight Attendant Complaints     1
# Late Flight\nLost Luggage                    1
# Bad Flight                                   1
# Lost Luggage\nDamaged Luggage                1
# Late Flight\nCancelled Flight                1
# Flight Attendant Complaints                  1
# Customer Service Issue\nLost Luggage         1
# Customer Service Issue\nCan't Tell           1
# Name: negativereason_gold, dtype: int64

# %%
data['negativereason_gold'] = data['negativereason_gold'].fillna("Can't Tell")

# %%
data.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment_confidence        0
# negativereason                   4864
# negativereason_confidence        3931
# airline                             0
# airline_sentiment_gold          13612
# name                                0
# negativereason_gold                 0
# retweet_count                       0
# tweet_coord                     12691
# tweet_created                       0
# tweet_location                   4406
# user_timezone                    4514
# sentiment                           0
# text_clean                          0
# dtype: int64

# %%
data['airline_sentiment_gold'].value_counts()
# Out:
# negative    32
# positive     4
# neutral      3
# Name: airline_sentiment_gold, dtype: int64

# %%
data['airline_sentiment_gold'] = data['airline_sentiment_gold'].fillna("negative")

# %%
data
# Out:
#                  tweet_id  airline_sentiment_confidence  \
# 0      570306133677760513                        1.0000
# 2      570301083672813571                        0.6837
# 3      570301031407624196                        1.0000
# 4      570300817074462722                        1.0000
# 5      570300767074181121                        1.0000
# ...                   ...                           ...
# 14634  569587691626622976                        0.6684
# 14636  569587371693355008                        1.0000
# 14637  569587242672398336                        1.0000
# 14638  569587188687634433                        1.0000
# 14639  569587140490866689                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                     0.6684        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                   negative        cairdin          Can't Tell
# 2                   negative     yvonnalynn          Can't Tell
# 3                   negative       jnardino          Can't Tell
# 4                   negative       jnardino          Can't Tell
# 5                   negative       jnardino          Can't Tell
# ...                      ...            ...                 ...
# 14634               negative  GolfWithWoody          Can't Tell
# 14636               negative       itsropes          Can't Tell
# 14637               negative       sanyabun          Can't Tell
# 14638               negative     SraJackson          Can't Tell
# 14639               negative      daviddtwu          Can't Tell
#
#        retweet_count tweet_coord              tweet_created tweet_location  \
# 0                  0         NaN  2015-02-24 11:35:52 -0800            NaN
# 2                  0         NaN  2015-02-24 11:15:48 -0800      Lets Play
# 3                  0         NaN  2015-02-24 11:15:36 -0800            NaN
# 4                  0         NaN  2015-02-24 11:14:45 -0800            NaN
# 5                  0         NaN  2015-02-24 11:14:33 -0800            NaN
# ...              ...         ...                        ...            ...
# 14634              0         NaN  2015-02-22 12:01:02 -0800            NaN
# 14636              0         NaN  2015-02-22 11:59:46 -0800          Texas
# 14637              0         NaN  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638              0         NaN  2015-02-22 11:59:02 -0800     New Jersey
# 14639              0         NaN  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment  \
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636                         NaN          1
# 14637                         NaN          0
# 14638  Eastern Time (US & Canada)          1
# 14639                         NaN          0
#
#                                               text_clean
# 0                       virginamerica what dhepburn said
# 2      virginamerica i didn t today must mean i need ...
# 3      virginamerica it s really aggressive to blast ...
# 4      virginamerica and it s a really big bad thing ...
# 5      virginamerica seriously would pay 30 a flight ...
# ...                                                  ...
# 14634           americanair right on cue with the delays
# 14636  americanair leaving over 20 minutes late fligh...
# 14637  americanair please bring american airlines to ...
# 14638  americanair you have my money you change my fl...
# 14639  americanair we have 8 ppl so we need 2 know ho...
#
# [13651 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment_confidence        0
# negativereason                   4864
# negativereason_confidence        3931
# airline                             0
# airline_sentiment_gold              0
# name                                0
# negativereason_gold                 0
# retweet_count                       0
# tweet_coord                     12691
# tweet_created                       0
# tweet_location                   4406
# user_timezone                    4514
# sentiment                           0
# text_clean                          0
# dtype: int64

# %%
data['tweet_coord'].value_counts()
# Out:
# [0.0, 0.0]                      154
# [40.64656067, -73.78334045]       6
# [40.64646912, -73.79133606]       3
# [32.91792297, -97.00367737]       3
# [32.82813261, -97.25115941]       2
#                                ...
# [45.58931882, -122.5959928]       1
# [39.85861725, -104.67232956]      1
# [39.85861339, -104.67232131]      1
# [26.37852293, -81.78472152]       1
# [40.64946781, -73.76624703]       1
# Name: tweet_coord, Length: 784, dtype: int64

# %%
data['tweet_coord'] = data['tweet_coord'].fillna("[0.0, 0.0]")

# %%
data
# Out:
#                  tweet_id  airline_sentiment_confidence  \
# 0      570306133677760513                        1.0000
# 2      570301083672813571                        0.6837
# 3      570301031407624196                        1.0000
# 4      570300817074462722                        1.0000
# 5      570300767074181121                        1.0000
# ...                   ...                           ...
# 14634  569587691626622976                        0.6684
# 14636  569587371693355008                        1.0000
# 14637  569587242672398336                        1.0000
# 14638  569587188687634433                        1.0000
# 14639  569587140490866689                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                         NaN                        NaN  Virgin America
# 2                         NaN                        NaN  Virgin America
# 3                  Bad Flight                     0.7033  Virgin America
# 4                  Can't Tell                     1.0000  Virgin America
# 5                  Can't Tell                     0.6842  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                     0.6684        American
# 14636  Customer Service Issue                     1.0000        American
# 14637                     NaN                        NaN        American
# 14638  Customer Service Issue                     0.6659        American
# 14639                     NaN                     0.0000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                   negative        cairdin          Can't Tell
# 2                   negative     yvonnalynn          Can't Tell
# 3                   negative       jnardino          Can't Tell
# 4                   negative       jnardino          Can't Tell
# 5                   negative       jnardino          Can't Tell
# ...                      ...            ...                 ...
# 14634               negative  GolfWithWoody          Can't Tell
# 14636               negative       itsropes          Can't Tell
# 14637               negative       sanyabun          Can't Tell
# 14638               negative     SraJackson          Can't Tell
# 14639               negative      daviddtwu          Can't Tell
#
#        retweet_count tweet_coord              tweet_created tweet_location  \
# 0                  0  [0.0, 0.0]  2015-02-24 11:35:52 -0800            NaN
# 2                  0  [0.0, 0.0]  2015-02-24 11:15:48 -0800      Lets Play
# 3                  0  [0.0, 0.0]  2015-02-24 11:15:36 -0800            NaN
# 4                  0  [0.0, 0.0]  2015-02-24 11:14:45 -0800            NaN
# 5                  0  [0.0, 0.0]  2015-02-24 11:14:33 -0800            NaN
# ...              ...         ...                        ...            ...
# 14634              0  [0.0, 0.0]  2015-02-22 12:01:02 -0800            NaN
# 14636              0  [0.0, 0.0]  2015-02-22 11:59:46 -0800          Texas
# 14637              0  [0.0, 0.0]  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638              0  [0.0, 0.0]  2015-02-22 11:59:02 -0800     New Jersey
# 14639              0  [0.0, 0.0]  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment  \
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636                         NaN          1
# 14637                         NaN          0
# 14638  Eastern Time (US & Canada)          1
# 14639                         NaN          0
#
#                                               text_clean
# 0                       virginamerica what dhepburn said
# 2      virginamerica i didn t today must mean i need ...
# 3      virginamerica it s really aggressive to blast ...
# 4      virginamerica and it s a really big bad thing ...
# 5      virginamerica seriously would pay 30 a flight ...
# ...                                                  ...
# 14634           americanair right on cue with the delays
# 14636  americanair leaving over 20 minutes late fligh...
# 14637  americanair please bring american airlines to ...
# 14638  americanair you have my money you change my fl...
# 14639  americanair we have 8 ppl so we need 2 know ho...
#
# [13651 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# tweet_id                           0
# airline_sentiment_confidence       0
# negativereason                  4864
# negativereason_confidence       3931
# airline                            0
# airline_sentiment_gold             0
# name                               0
# negativereason_gold                0
# retweet_count                      0
# tweet_coord                        0
# tweet_created                      0
# tweet_location                  4406
# user_timezone                   4514
# sentiment                          0
# text_clean                         0
# dtype: int64

# %%
data['negativereason'].value_counts()
# Out:
# Customer Service Issue         2833
# Late Flight                    1605
# Can't Tell                     1103
# Cancelled Flight                805
# Lost Luggage                    696
# Bad Flight                      553
# Flight Booking Problems         484
# Flight Attendant Complaints     467
# longlines                       169
# Damaged Luggage                  72
# Name: negativereason, dtype: int64

# %%
data['negativereason'] = data['negativereason'].fillna("Can't Tell")

# %%
data.isnull().sum()
# Out:
# tweet_id                           0
# airline_sentiment_confidence       0
# negativereason                     0
# negativereason_confidence       3931
# airline                            0
# airline_sentiment_gold             0
# name                               0
# negativereason_gold                0
# retweet_count                      0
# tweet_coord                        0
# tweet_created                      0
# tweet_location                  4406
# user_timezone                   4514
# sentiment                          0
# text_clean                         0
# dtype: int64

# %%
data['negativereason_confidence'].value_counts()
# Out:
# 1.0000    3436
# 0.0000     933
# 0.6667      62
# 0.6632      33
# 0.6596      29
#           ...
# 0.3420       1
# 0.4039       1
# 0.3623       1
# 0.3278       1
# 0.7255       1
# Name: negativereason_confidence, Length: 1317, dtype: int64

# %%
data["negativereason_confidence"] = pd.to_numeric(data["negativereason_confidence"], errors="coerce")
data["negativereason_confidence"].fillna(data["negativereason_confidence"].mean(), inplace=True)

# %%
data
# Out:
#                  tweet_id  airline_sentiment_confidence  \
# 0      570306133677760513                        1.0000
# 2      570301083672813571                        0.6837
# 3      570301031407624196                        1.0000
# 4      570300817074462722                        1.0000
# 5      570300767074181121                        1.0000
# ...                   ...                           ...
# 14634  569587691626622976                        0.6684
# 14636  569587371693355008                        1.0000
# 14637  569587242672398336                        1.0000
# 14638  569587188687634433                        1.0000
# 14639  569587140490866689                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                  Can't Tell                   0.672214  Virgin America
# 2                  Can't Tell                   0.672214  Virgin America
# 3                  Bad Flight                   0.703300  Virgin America
# 4                  Can't Tell                   1.000000  Virgin America
# 5                  Can't Tell                   0.684200  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                   0.668400        American
# 14636  Customer Service Issue                   1.000000        American
# 14637              Can't Tell                   0.672214        American
# 14638  Customer Service Issue                   0.665900        American
# 14639              Can't Tell                   0.000000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                   negative        cairdin          Can't Tell
# 2                   negative     yvonnalynn          Can't Tell
# 3                   negative       jnardino          Can't Tell
# 4                   negative       jnardino          Can't Tell
# 5                   negative       jnardino          Can't Tell
# ...                      ...            ...                 ...
# 14634               negative  GolfWithWoody          Can't Tell
# 14636               negative       itsropes          Can't Tell
# 14637               negative       sanyabun          Can't Tell
# 14638               negative     SraJackson          Can't Tell
# 14639               negative      daviddtwu          Can't Tell
#
#        retweet_count tweet_coord              tweet_created tweet_location  \
# 0                  0  [0.0, 0.0]  2015-02-24 11:35:52 -0800            NaN
# 2                  0  [0.0, 0.0]  2015-02-24 11:15:48 -0800      Lets Play
# 3                  0  [0.0, 0.0]  2015-02-24 11:15:36 -0800            NaN
# 4                  0  [0.0, 0.0]  2015-02-24 11:14:45 -0800            NaN
# 5                  0  [0.0, 0.0]  2015-02-24 11:14:33 -0800            NaN
# ...              ...         ...                        ...            ...
# 14634              0  [0.0, 0.0]  2015-02-22 12:01:02 -0800            NaN
# 14636              0  [0.0, 0.0]  2015-02-22 11:59:46 -0800          Texas
# 14637              0  [0.0, 0.0]  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638              0  [0.0, 0.0]  2015-02-22 11:59:02 -0800     New Jersey
# 14639              0  [0.0, 0.0]  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment  \
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636                         NaN          1
# 14637                         NaN          0
# 14638  Eastern Time (US & Canada)          1
# 14639                         NaN          0
#
#                                               text_clean
# 0                       virginamerica what dhepburn said
# 2      virginamerica i didn t today must mean i need ...
# 3      virginamerica it s really aggressive to blast ...
# 4      virginamerica and it s a really big bad thing ...
# 5      virginamerica seriously would pay 30 a flight ...
# ...                                                  ...
# 14634           americanair right on cue with the delays
# 14636  americanair leaving over 20 minutes late fligh...
# 14637  americanair please bring american airlines to ...
# 14638  americanair you have my money you change my fl...
# 14639  americanair we have 8 ppl so we need 2 know ho...
#
# [13651 rows x 15 columns]

# %%
data["tweet_location"] = data["tweet_location"].fillna("Boston, MA")

# %%
data["user_timezone"].value_counts()
# Out:
# Eastern Time (US & Canada)    3464
# Central Time (US & Canada)    1807
# Pacific Time (US & Canada)    1109
# Quito                          705
# Atlantic Time (Canada)         458
#                               ...
# Prague                           1
# Bucharest                        1
# Bern                             1
# Irkutsk                          1
# Perth                            1
# Name: user_timezone, Length: 83, dtype: int64

# %%
data["user_timezone"] = data["user_timezone"].fillna("Eastern Time (US & Canada)")

# %%
data.isnull().sum()
# Out:
# tweet_id                        0
# airline_sentiment_confidence    0
# negativereason                  0
# negativereason_confidence       0
# airline                         0
# airline_sentiment_gold          0
# name                            0
# negativereason_gold             0
# retweet_count                   0
# tweet_coord                     0
# tweet_created                   0
# tweet_location                  0
# user_timezone                   0
# sentiment                       0
# text_clean                      0
# dtype: int64

# %%
data
# Out:
#                  tweet_id  airline_sentiment_confidence  \
# 0      570306133677760513                        1.0000
# 2      570301083672813571                        0.6837
# 3      570301031407624196                        1.0000
# 4      570300817074462722                        1.0000
# 5      570300767074181121                        1.0000
# ...                   ...                           ...
# 14634  569587691626622976                        0.6684
# 14636  569587371693355008                        1.0000
# 14637  569587242672398336                        1.0000
# 14638  569587188687634433                        1.0000
# 14639  569587140490866689                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# 0                  Can't Tell                   0.672214  Virgin America
# 2                  Can't Tell                   0.672214  Virgin America
# 3                  Bad Flight                   0.703300  Virgin America
# 4                  Can't Tell                   1.000000  Virgin America
# 5                  Can't Tell                   0.684200  Virgin America
# ...                       ...                        ...             ...
# 14634             Late Flight                   0.668400        American
# 14636  Customer Service Issue                   1.000000        American
# 14637              Can't Tell                   0.672214        American
# 14638  Customer Service Issue                   0.665900        American
# 14639              Can't Tell                   0.000000        American
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                   negative        cairdin          Can't Tell
# 2                   negative     yvonnalynn          Can't Tell
# 3                   negative       jnardino          Can't Tell
# 4                   negative       jnardino          Can't Tell
# 5                   negative       jnardino          Can't Tell
# ...                      ...            ...                 ...
# 14634               negative  GolfWithWoody          Can't Tell
# 14636               negative       itsropes          Can't Tell
# 14637               negative       sanyabun          Can't Tell
# 14638               negative     SraJackson          Can't Tell
# 14639               negative      daviddtwu          Can't Tell
#
#        retweet_count tweet_coord              tweet_created tweet_location  \
# 0                  0  [0.0, 0.0]  2015-02-24 11:35:52 -0800     Boston, MA
# 2                  0  [0.0, 0.0]  2015-02-24 11:15:48 -0800      Lets Play
# 3                  0  [0.0, 0.0]  2015-02-24 11:15:36 -0800     Boston, MA
# 4                  0  [0.0, 0.0]  2015-02-24 11:14:45 -0800     Boston, MA
# 5                  0  [0.0, 0.0]  2015-02-24 11:14:33 -0800     Boston, MA
# ...              ...         ...                        ...            ...
# 14634              0  [0.0, 0.0]  2015-02-22 12:01:02 -0800     Boston, MA
# 14636              0  [0.0, 0.0]  2015-02-22 11:59:46 -0800          Texas
# 14637              0  [0.0, 0.0]  2015-02-22 11:59:15 -0800  Nigeria,lagos
# 14638              0  [0.0, 0.0]  2015-02-22 11:59:02 -0800     New Jersey
# 14639              0  [0.0, 0.0]  2015-02-22 11:58:51 -0800     dallas, TX
#
#                     user_timezone  sentiment  \
# 0      Eastern Time (US & Canada)          0
# 2      Central Time (US & Canada)          0
# 3      Pacific Time (US & Canada)          1
# 4      Pacific Time (US & Canada)          1
# 5      Pacific Time (US & Canada)          1
# ...                           ...        ...
# 14634                       Quito          1
# 14636  Eastern Time (US & Canada)          1
# 14637  Eastern Time (US & Canada)          0
# 14638  Eastern Time (US & Canada)          1
# 14639  Eastern Time (US & Canada)          0
#
#                                               text_clean
# 0                       virginamerica what dhepburn said
# 2      virginamerica i didn t today must mean i need ...
# 3      virginamerica it s really aggressive to blast ...
# 4      virginamerica and it s a really big bad thing ...
# 5      virginamerica seriously would pay 30 a flight ...
# ...                                                  ...
# 14634           americanair right on cue with the delays
# 14636  americanair leaving over 20 minutes late fligh...
# 14637  americanair please bring american airlines to ...
# 14638  americanair you have my money you change my fl...
# 14639  americanair we have 8 ppl so we need 2 know ho...
#
# [13651 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# tweet_id                        0
# airline_sentiment_confidence    0
# negativereason                  0
# negativereason_confidence       0
# airline                         0
# airline_sentiment_gold          0
# name                            0
# negativereason_gold             0
# retweet_count                   0
# tweet_coord                     0
# tweet_created                   0
# tweet_location                  0
# user_timezone                   0
# sentiment                       0
# text_clean                      0
# dtype: int64
